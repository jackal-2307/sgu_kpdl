# %% [markdown]
# Tìm hiểu thư viện apyori **(https://pypi.org/project/apyori)** để thực hiện tìm luật kết hợp từ tập phổ
# biến từ dữ liệu mua hàng tại siêu thị. Tham khảo bài hướng dẫn
# https://www.kaggle.com/code/rockystats/apriori-algorithm-or-market-basket-analysis

# %% [markdown]
# #### Apriori (apyori) cho Market_Basket_Optimisation.csv

# %% [markdown]
# 1. Import thư viện

# %%
#import all required packages..
import pandas as pd
import numpy as np
from apyori import apriori

# %% [markdown]
# 2. Chuẩn bị dữ liệu

# %%
# đọc dữ liệu (mỗi dòng là 1 giao dịch, tối đa 20 mặt hàng)
df = pd.read_csv("Data/Market_Basket_Optimisation.csv", header=None)

# chuyển sang dạng list transactions (list of list)
transactions = []
for i in range(df.shape[0]):
    items = df.iloc[i].dropna().astype(str).str.strip().tolist()
    items = [x for x in items if x and x.lower() != "nan"]
    transactions.append(items)

# %% [markdown]
# 3. Chạy Apriori (apyori) để lấy luật kết hợp

# %%
rules = apriori(
    transactions,
    min_support=0.003,      # ~0.3%
    min_confidence=0.2,
    min_lift=3,
    min_length=2
)

results = list(rules)
print("Số RelationRecord tìm được:", len(results))
# Out:
# Số RelationRecord tìm được: 80

# %% [markdown]
# 4. Trích xuất luật ra bảng (support / confidence / lift)

# %%
import pandas as pd

rows = []
for r in results:
    for stat in r.ordered_statistics:
        if len(stat.items_base) == 0 or len(stat.items_add) == 0:
            continue
        rows.append({
            "antecedent": ", ".join(sorted(stat.items_base)),
            "consequent": ", ".join(sorted(stat.items_add)),
            "support": r.support,
            "confidence": stat.confidence,
            "lift": stat.lift
        })

rules_df = pd.DataFrame(rows)

# top 10 luật theo lift rồi confidence
top10 = rules_df.sort_values(["lift","confidence","support"], ascending=False).head(10)
top10
# Out:
#                                  antecedent                        consequent  \
# 107                 frozen vegetables, soup               milk, mineral water
# 103            frozen vegetables, olive oil               milk, mineral water
# 69         mineral water, whole wheat pasta                         olive oil
# 108                              milk, soup  frozen vegetables, mineral water
# 56                             tomato sauce            ground beef, spaghetti
# 109  frozen vegetables, milk, mineral water                              soup
# 3                             fromage blanc                             honey
# 58                  spaghetti, tomato sauce                       ground beef
# 0                               light cream                           chicken
# 2                                     pasta                          escalope
#
#       support  confidence      lift
# 107  0.003066    0.383333  7.987176
# 103  0.003333    0.294118  6.128268
# 69   0.003866    0.402778  6.115863
# 108  0.003066    0.201754  5.646864
# 56   0.003066    0.216981  5.535971
# 109  0.003066    0.277108  5.484407
# 3    0.003333    0.245098  5.164271
# 58   0.003066    0.489362  4.980600
# 0    0.004533    0.290598  4.843951
# 2    0.005866    0.372881  4.700812

# %% [markdown]
# 5. Lưu kết quả cho Market_Basket_Optimisation.csv

# %%
# Lưu toàn bộ luật
rules_df.to_csv(
    "apyori_rules_marketbasket_all.csv",
    index=False,
    encoding="utf-8-sig"
)

# Lưu top 10 luật
top10.to_csv(
    "apyori_rules_marketbasket_top10.csv",
    index=False,
    encoding="utf-8-sig"
)

print("Saved Market Basket rules to CSV files")
# Out:
# Saved Market Basket rules to CSV files

# %% [markdown]
# #### Apriori (apyori) cho data-2.csv

# %% [markdown]
# 1. Đọc dữ liệu

# %%
# đọc file data-2.csv
df = pd.read_csv("Data/data-2.csv/data-2.csv")
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# 2. Làm sạch dữ liệu

# %%
# chuyển InvoiceNo sang string
df["InvoiceNo"] = df["InvoiceNo"].astype(str)

# loại hóa đơn hủy (InvoiceNo chứa 'C')
df = df[~df["InvoiceNo"].str.contains("C", na=False)]

# loại số lượng <= 0
df = df[df["Quantity"] > 0]

# loại dòng thiếu dữ liệu
df = df.dropna(subset=["InvoiceNo", "Description"])

# làm sạch tên sản phẩm
df["Description"] = df["Description"].astype(str).str.strip()
df = df[df["Description"] != ""]

# %% [markdown]
# 3. Tạo danh sách giao dịch (transactions)
# - Mỗi InvoiceNo = 1 giao dịch, mỗi giao dịch là danh sách sản phẩm.

# %%
transactions = (
    df.groupby("InvoiceNo")["Description"]
      .apply(lambda x: list(pd.unique(x)))
      .tolist()
)

print("Number of transactions:", len(transactions))
print("Average basket size:", np.mean([len(t) for t in transactions]))
# Out:
# Number of transactions: 20136
# Average basket size: 25.81768970997219

# %% [markdown]
# 4. (Khuyến nghị) Loại giỏ hàng quá lớn
# - Data-2 thường có invoice rất lớn → lọc để luật có ý nghĩa.

# %%
basket_size = df.groupby("InvoiceNo")["Description"].nunique()
valid_invoices = basket_size[basket_size <= 200].index

df = df[df["InvoiceNo"].isin(valid_invoices)]

transactions = (
    df.groupby("InvoiceNo")["Description"]
      .apply(lambda x: list(pd.unique(x)))
      .tolist()
)

print("Transactions after filtering:", len(transactions))
# Out:
# Transactions after filtering: 19900

# %% [markdown]
# 5. Chạy Apriori bằng apyori

# %%
rules = apriori(
    transactions,
    min_support=0.01,      # 1%
    min_confidence=0.3,
    min_lift=3,
    min_length=2,
    max_length=3
)

results = list(rules)
print("Number of association rules:", len(results))
# Out:
# Number of association rules: 423

# %% [markdown]
# 6. Chuyển kết quả sang DataFrame

# %%
rows = []
for r in results:
    for stat in r.ordered_statistics:
        if len(stat.items_base) == 0 or len(stat.items_add) == 0:
            continue
        rows.append({
            "Antecedent": ", ".join(stat.items_base),
            "Consequent": ", ".join(stat.items_add),
            "Support": r.support,
            "Confidence": stat.confidence,
            "Lift": stat.lift
        })

rules_df = pd.DataFrame(rows)
rules_df.head()
# Out:
#                        Antecedent                          Consequent  \
# 0     60 TEATIME FAIRY CAKE CASES      72 SWEETHEART FAIRY CAKE CASES
# 1  72 SWEETHEART FAIRY CAKE CASES         60 TEATIME FAIRY CAKE CASES
# 2     60 TEATIME FAIRY CAKE CASES      PACK OF 60 DINOSAUR CAKE CASES
# 3  PACK OF 60 DINOSAUR CAKE CASES         60 TEATIME FAIRY CAKE CASES
# 4     60 TEATIME FAIRY CAKE CASES  PACK OF 60 PINK PAISLEY CAKE CASES
#
#     Support  Confidence       Lift
# 0  0.011809    0.318860  11.838281
# 1  0.011809    0.438433  11.838281
# 2  0.011457    0.309362  11.337586
# 3  0.011457    0.419890  11.337586
# 4  0.015276    0.412483  10.872070

# %% [markdown]
# 7. Top 10 luật kết hợp mạnh nhất (theo Lift)

# %%
top10_rules = rules_df.sort_values(
    ["Lift", "Confidence", "Support"],
    ascending=False
).head(10)

top10_rules
# Out:
#                                            Antecedent  \
# 154                              HERB MARKER ROSEMARY
# 155                                 HERB MARKER THYME
# 867                            REGENCY TEA PLATE PINK
# 870  REGENCY TEA PLATE ROSES, REGENCY TEA PLATE GREEN
# 871   REGENCY TEA PLATE PINK, REGENCY TEA PLATE ROSES
# 866                           REGENCY TEA PLATE GREEN
# 441                            REGENCY TEA PLATE PINK
# 440                           REGENCY TEA PLATE GREEN
# 435                          REGENCY SUGAR BOWL GREEN
# 434                             REGENCY MILK JUG PINK
#
#                                            Consequent   Support  Confidence  \
# 154                                 HERB MARKER THYME  0.010101    0.934884
# 155                              HERB MARKER ROSEMARY  0.010101    0.934884
# 867  REGENCY TEA PLATE GREEN, REGENCY TEA PLATE ROSES  0.010352    0.830645
# 870                            REGENCY TEA PLATE PINK  0.010352    0.804688
# 871                           REGENCY TEA PLATE GREEN  0.010352    0.944954
# 866   REGENCY TEA PLATE PINK, REGENCY TEA PLATE ROSES  0.010352    0.671010
# 441                           REGENCY TEA PLATE GREEN  0.011307    0.907258
# 440                            REGENCY TEA PLATE PINK  0.011307    0.732899
# 435                             REGENCY MILK JUG PINK  0.011106    0.775439
# 434                          REGENCY SUGAR BOWL GREEN  0.011106    0.764706
#
#           Lift
# 154  86.531098
# 155  86.531098
# 867  64.569682
# 870  64.569682
# 871  61.252727
# 866  61.252727
# 441  58.809236
# 440  58.809236
# 435  53.395253
# 434  53.395253

# %% [markdown]
# 8. Lưu kết quả cho data-2.csv

# %%
top10_rules.to_csv("apyori_rules_data2_top10.csv", index=False)
rules_df.to_csv("apyori_rules_data2_all.csv", index=False)
